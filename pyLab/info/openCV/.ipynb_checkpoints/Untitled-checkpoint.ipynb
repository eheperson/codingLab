# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
print("openCV version : ",cv2.__version__)
# Out:
# openCV version :  4.4.0

# %%
# see python.exe location
import sys
print("python.exe location : ",sys.executable)

#see working directory 
import os
print("\nWorking directory   : ",os.getcwd())
# Out:
# python.exe location :  c:\users\kuzub\miniconda3\envs\testenv\python.exe
#
# Working directory   :  C:\Users\kuzub\Desktop\githubRepos\codingLab\pyLab\openCV
