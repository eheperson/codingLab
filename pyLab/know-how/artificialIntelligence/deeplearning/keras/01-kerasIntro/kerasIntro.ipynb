# %%
import keras as k

from keras import backend as b
from keras.models import Sequential
from keras.layers import Activation, Dropout
from keras.layers.core import Dense, Flatten
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import *

# %% [markdown]
# <h1> Comosing Model in Keras </h1>

# %% [markdown]
# <h3> Sequential Composition </h3>

# %%
model = Sequential()

nHidden = 2
model.add(Dense(nHidden, input_shape=(748,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))

nHidden = 2
model.add(Dense(nHidden, input_shape=(748,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))

nHidden = 2
model.add(Dense(nHidden, input_shape=(748,)))
model.add(Activation('relu'))

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_10 (Dense)             (None, 2)                 1498
# _________________________________________________________________
# activation_9 (Activation)    (None, 2)                 0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2)                 0
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 6
# _________________________________________________________________
# activation_10 (Activation)   (None, 2)                 0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 2)                 0
# _________________________________________________________________
# dense_12 (Dense)             (None, 2)                 6
# ...

# %% [markdown]
# <h3> Functional Composition </h3>
# <p>The second way of composing modules is via the function API, where it is possimbe to define complex models.>Keras functional API defines each layer as a function and provides operators to compose these functions into a larger computational graph</p>
# <a href="https://keras.io/getting-started/functional-api-guide/"> click for more information </a>

# %% [markdown]
# <h1> Compilation </h1>
# <h4>
#     Before training a model, we needto configure the learning process, using the compile method. It receives 3 arguments : </h4>
# <br>
# <dl>
#     <dt> 1 - An optimizer : </dt>
#     <dd>
#         It could be the string identifier of an optimizer such as 'rmsprop' or 'adam', or an instance of the optimizer
#         class
#     </dd>
#     <dt> 2 - A Loss Function : </dt>
#     <dd>
#         This is the objective function to minimize. It can be the string identifier of a loss function such as; 'categorical_crossentropy' or 'rmse', or it can be an objective function.
#     </dd>
#     <dt> 3 - A List Of Metrics : </dt>
#     <dd>
#         It could be the string identifier of a metric such as : metrics=['accuracy']
#     </dd>
# </dl>

# %% [markdown]
# <h1> Training </h1>
#
# <p>
#     For training the model you need to use the function fit. Keras models are trained on Numpy arrays of input data and labels.
# </p>
