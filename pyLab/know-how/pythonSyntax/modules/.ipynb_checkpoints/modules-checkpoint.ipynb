# %%
import os
dir(os)
os.name
# 'nt' for windows users
#'posix' for others


#from os import name
#name

from os import name, listdir, getcwd

# %%
if os.name != 'nt':
    print('That program only for windows users!')
else
    print('welcome')
# Out:
# welcome

# %%
#creates folder
os.makedirs('testDirectory')

#shos working directory
os.getcwd()
# Out:
# 'C:\\Users\\kuzub\\Desktop\\githubRepos\\codingLab\\pyLab\\oop'

# %%
import sys

# shows python version
sys.version
# Out:
# '3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]'

# %%
import webbrowser as web
web.open('www.youtube.com.tr')

# %%
import subprocess
#import subprocess as sp
subprocess.call('notepad.exe')
